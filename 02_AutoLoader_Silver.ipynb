# %%
df = spark.table(
    "mythri_databricks.etl_demo.customers_autoloader_bronze"
)

silver_df = df.dropDuplicates()

display(silver_df)

# %%
silver_df.write.mode("overwrite").saveAsTable(
    "mythri_databricks.etl_demo.customers_autoloader_silver"
)
