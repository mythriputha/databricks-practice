# %%
result = dbutils.notebook.run(
    "/Workspace/Users/puthamythri@gmail.com/04_Notebook_To_Notebook",
    300,
    {
        "source_table": "mythri_databricks.sales_bronze.customers_bronze"
    }
)

print(result)
